# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

import traceback

# %%
# Import the requests library.
import requests

# # Import the API key(from the main folder)
# from World_Weather_Analysis.app.folder.config.py import weather_api_key

import sys
sys.path.append("..")
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        print("city name is ", city)
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

        # If an error is experienced, skip the city.
    except Exception as e:
        traceback.print_exc()
        print("error in the code is", e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 16 | rikitea
# city name is  rikitea
# Processing Record 2 of Set 16 | lebu
# city name is  lebu
# Processing Record 3 of Set 16 | icod de los vinos
# city name is  icod de los vinos
# Processing Record 4 of Set 16 | nikolskoye
# city name is  nikolskoye
# Processing Record 5 of Set 16 | sao felix do xingu
# city name is  sao felix do xingu
# Processing Record 6 of Set 16 | taolanaro
# city name is  taolanaro
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 7 of Set 16 | carnarvon
# city name is  carnarvon
# Processing Record 8 of Set 16 | mar del plata
# city name is  mar del plata
# Processing Record 9 of Set 16 | new norfolk
# city name is  new norfolk
# Processing Record 10 of Set 16 | bandar-e lengeh
# city name is  bandar-e lengeh
# Processing Record 11 of Set 16 | lorengau
# city name is  lorengau
# Processing Record 12 of Set 16 | mbalmayo
# city name is  mbalmayo
# Processing Record 13 of Set 16 | iseyin
# city name is  iseyin
# Processing Record 14 of Set 16 | marawi
# city name is  marawi
# Processing Record 15 of Set 16 | ushuaia
# city name is  ushuaia
# Processing Record 16 of Set 16 | bajil
# city name is  bajil
# Processing Record 17 of Set 16 | yeniseysk
# city name is  yeniseysk
# Processing Record 18 of Set 16 | arraial do cabo
# city name is  arraial do cabo
# Processing Record 19 of Set 16 | andros town
# city name is  andros town
# Processing Record 20 of Set 16 | nuuk
# city name is  nuuk
# Processing Record 21 of Set 16 | kushiro
# city name is  kushiro
# Processing Record 22 of Set 16 | barrow
# city name is  barrow
# Processing Record 23 of Set 16 | busselton
# city name is  busselton
# Processing Record 24 of Set 16 | tecpatan
# city name is  tecpatan
# Processing Record 25 of Set 16 | vaini
# city name is  vaini
# Processing Record 26 of Set 16 | tasiilaq
# city name is  tasiilaq
# Processing Record 27 of Set 16 | vuktyl
# city name is  vuktyl
# Processing Record 28 of Set 16 | kazalinsk
# city name is  kazalinsk
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 29 of Set 16 | itoman
# city name is  itoman
# Processing Record 30 of Set 16 | sentyabrskiy
# city name is  sentyabrskiy
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 31 of Set 16 | albany
# city name is  albany
# Processing Record 32 of Set 16 | castel san giovanni
# city name is  castel san giovanni
# Processing Record 33 of Set 16 | duvan
# city name is  duvan
# Processing Record 34 of Set 16 | chuy
# city name is  chuy
# Processing Record 35 of Set 16 | kathmandu
# city name is  kathmandu
# Processing Record 36 of Set 16 | jamestown
# city name is  jamestown
# Processing Record 37 of Set 16 | yabelo
# city name is  yabelo
# Processing Record 38 of Set 16 | kapaa
# city name is  kapaa
# Processing Record 39 of Set 16 | punta arenas
# city name is  punta arenas
# Processing Record 40 of Set 16 | nanortalik
# city name is  nanortalik
# Processing Record 41 of Set 16 | karratha
# city name is  karratha
# Processing Record 42 of Set 16 | tuktoyaktuk
# city name is  tuktoyaktuk
# Processing Record 43 of Set 16 | mataura
# city name is  mataura
# Processing Record 44 of Set 16 | hobart
# city name is  hobart
# Processing Record 45 of Set 16 | hermanus
# city name is  hermanus
# Processing Record 46 of Set 16 | khatanga
# city name is  khatanga
# Processing Record 47 of Set 16 | avarua
# city name is  avarua
# Processing Record 48 of Set 16 | voh
# city name is  voh
# Processing Record 49 of Set 16 | bethel
# city name is  bethel
# Processing Record 50 of Set 16 | algiers
# city name is  algiers
# Processing Record 1 of Set 17 | huancavelica
# city name is  huancavelica
# Processing Record 2 of Set 17 | pangnirtung
# city name is  pangnirtung
# Processing Record 3 of Set 17 | umzimvubu
# city name is  umzimvubu
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 4 of Set 17 | morgan city
# city name is  morgan city
# Processing Record 5 of Set 17 | samalaeulu
# city name is  samalaeulu
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 6 of Set 17 | pineville
# city name is  pineville
# Processing Record 7 of Set 17 | del rio
# city name is  del rio
# Processing Record 8 of Set 17 | longyearbyen
# city name is  longyearbyen
# Processing Record 9 of Set 17 | yatou
# city name is  yatou
# Processing Record 10 of Set 17 | barawe
# city name is  barawe
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 11 of Set 17 | westport
# city name is  westport
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 12 of Set 17 | polunochnoye
# city name is  polunochnoye
# Processing Record 13 of Set 17 | khromtau
# city name is  khromtau
# Processing Record 14 of Set 17 | clyde river
# city name is  clyde river
# Processing Record 15 of Set 17 | quatre cocos
# city name is  quatre cocos
# Processing Record 16 of Set 17 | tsihombe
# city name is  tsihombe
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 17 of Set 17 | airai
# city name is  airai
# Processing Record 18 of Set 17 | mount gambier
# city name is  mount gambier
# Processing Record 19 of Set 17 | ribeira grande
# city name is  ribeira grande
# Processing Record 20 of Set 17 | bredasdorp
# city name is  bredasdorp
# Processing Record 21 of Set 17 | malveira
# city name is  malveira
# Processing Record 22 of Set 17 | buta
# city name is  buta
# Processing Record 23 of Set 17 | matsanga
# city name is  matsanga
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 24 of Set 17 | almirante
# city name is  almirante
# Processing Record 25 of Set 17 | mahebourg
# city name is  mahebourg
# Processing Record 26 of Set 17 | belushya guba
# city name is  belushya guba
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 27 of Set 17 | cape town
# city name is  cape town
# Processing Record 28 of Set 17 | illoqqortoormiut
# city name is  illoqqortoormiut
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 29 of Set 17 | tuatapere
# city name is  tuatapere
# Processing Record 30 of Set 17 | conceicao da barra
# city name is  conceicao da barra
# Processing Record 31 of Set 17 | port hardy
# city name is  port hardy
# Processing Record 32 of Set 17 | fortuna
# city name is  fortuna
# Processing Record 33 of Set 17 | san jose
# city name is  san jose
# Processing Record 34 of Set 17 | fevralsk
# city name is  fevralsk
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 35 of Set 17 | sompeta
# city name is  sompeta
# Processing Record 36 of Set 17 | turukhansk
# city name is  turukhansk
# Processing Record 37 of Set 17 | rudbar
# city name is  rudbar
# Processing Record 38 of Set 17 | oriximina
# city name is  oriximina
# Processing Record 39 of Set 17 | thompson
# city name is  thompson
# Processing Record 40 of Set 17 | kailua
# city name is  kailua
# Processing Record 41 of Set 17 | namibe
# city name is  namibe
# Processing Record 42 of Set 17 | prudyanka
# city name is  prudyanka
# Processing Record 43 of Set 17 | cherskiy
# city name is  cherskiy
# Processing Record 44 of Set 17 | thinadhoo
# city name is  thinadhoo
# Processing Record 45 of Set 17 | show low
# city name is  show low
# Processing Record 46 of Set 17 | bereda
# city name is  bereda
# Processing Record 47 of Set 17 | liverpool
# city name is  liverpool
# Processing Record 48 of Set 17 | mys shmidta
# city name is  mys shmidta
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 49 of Set 17 | klaksvik
# city name is  klaksvik
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 50 of Set 17 | broken hill
# city name is  broken hill
# Processing Record 1 of Set 18 | cap-aux-meules
# city name is  cap-aux-meules
# Processing Record 2 of Set 18 | bluff
# city name is  bluff
# Processing Record 3 of Set 18 | maldonado
# city name is  maldonado
# Processing Record 4 of Set 18 | zhuhai
# city name is  zhuhai
# Processing Record 5 of Set 18 | qaanaaq
# city name is  qaanaaq
# Processing Record 6 of Set 18 | moose factory
# city name is  moose factory
# Processing Record 7 of Set 18 | sibolga
# city name is  sibolga
# Processing Record 8 of Set 18 | tiksi
# city name is  tiksi
# Processing Record 9 of Set 18 | georgetown
# city name is  georgetown
# Processing Record 10 of Set 18 | manoel urbano
# city name is  manoel urbano
# Processing Record 11 of Set 18 | santa ana
# city name is  santa ana
# Processing Record 12 of Set 18 | husavik
# city name is  husavik
# Processing Record 13 of Set 18 | bolshiye uki
# city name is  bolshiye uki
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 14 of Set 18 | saskylakh
# city name is  saskylakh
# Processing Record 15 of Set 18 | asfi
# city name is  asfi
# Processing Record 16 of Set 18 | lata
# city name is  lata
# Processing Record 17 of Set 18 | shupiyan
# city name is  shupiyan
# Processing Record 18 of Set 18 | zhenlai
# city name is  zhenlai
# Processing Record 19 of Set 18 | codrington
# city name is  codrington
# Processing Record 20 of Set 18 | hithadhoo
# city name is  hithadhoo
# Processing Record 21 of Set 18 | tilichiki
# city name is  tilichiki
# Processing Record 22 of Set 18 | upernavik
# city name is  upernavik
# Processing Record 23 of Set 18 | grand river south east
# city name is  grand river south east
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 24 of Set 18 | puerto colombia
# city name is  puerto colombia
# Processing Record 25 of Set 18 | cheuskiny
# city name is  cheuskiny
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 26 of Set 18 | yellowknife
# city name is  yellowknife
# Processing Record 27 of Set 18 | wageningen
# city name is  wageningen
# Processing Record 28 of Set 18 | plouzane
# city name is  plouzane
# Processing Record 29 of Set 18 | guadalajara
# city name is  guadalajara
# Processing Record 30 of Set 18 | rocha
# city name is  rocha
# Processing Record 31 of Set 18 | sao filipe
# city name is  sao filipe
# Processing Record 32 of Set 18 | saldanha
# city name is  saldanha
# Processing Record 33 of Set 18 | cidreira
# city name is  cidreira
# Processing Record 34 of Set 18 | ancud
# city name is  ancud
# Processing Record 35 of Set 18 | lagoa
# city name is  lagoa
# Processing Record 36 of Set 18 | general roca
# city name is  general roca
# Processing Record 37 of Set 18 | ilulissat
# city name is  ilulissat
# Processing Record 38 of Set 18 | harper
# city name is  harper
# Processing Record 39 of Set 18 | roald
# city name is  roald
# Processing Record 40 of Set 18 | souillac
# city name is  souillac
# Processing Record 41 of Set 18 | vardo
# city name is  vardo
# Processing Record 42 of Set 18 | atar
# city name is  atar
# Processing Record 43 of Set 18 | xichang
# city name is  xichang
# Processing Record 44 of Set 18 | krasnoselkup
# city name is  krasnoselkup
# Processing Record 45 of Set 18 | bagdarin
# city name is  bagdarin
# Processing Record 46 of Set 18 | baykit
# city name is  baykit
# Processing Record 47 of Set 18 | srednekolymsk
# city name is  srednekolymsk
# Processing Record 48 of Set 18 | puerto ayora
# city name is  puerto ayora
# Processing Record 49 of Set 18 | poum
# city name is  poum
# Processing Record 50 of Set 18 | barentsburg
# city name is  barentsburg
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 1 of Set 19 | kavieng
# city name is  kavieng
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 2 of Set 19 | saint-philippe
# city name is  saint-philippe
# Processing Record 3 of Set 19 | inhambane
# city name is  inhambane
# Processing Record 4 of Set 19 | vao
# city name is  vao
# Processing Record 5 of Set 19 | sao jose da coroa grande
# city name is  sao jose da coroa grande
# Processing Record 6 of Set 19 | kerteh
# city name is  kerteh
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 7 of Set 19 | dunedin
# city name is  dunedin
# Processing Record 8 of Set 19 | skibbereen
# city name is  skibbereen
# Processing Record 9 of Set 19 | atuona
# city name is  atuona
# Processing Record 10 of Set 19 | cairns
# city name is  cairns
# Processing Record 11 of Set 19 | muyezerskiy
# city name is  muyezerskiy
# Processing Record 12 of Set 19 | camacha
# city name is  camacha
# Processing Record 13 of Set 19 | denau
# city name is  denau
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 14 of Set 19 | ponta do sol
# city name is  ponta do sol
# Processing Record 15 of Set 19 | changqing
# city name is  changqing
# Processing Record 16 of Set 19 | sambava
# city name is  sambava
# Processing Record 17 of Set 19 | butaritari
# city name is  butaritari
# Processing Record 18 of Set 19 | yirol
# city name is  yirol
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 19 of Set 19 | touros
# city name is  touros
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 20 of Set 19 | castro
# city name is  castro
# Processing Record 21 of Set 19 | veraval
# city name is  veraval
# Processing Record 22 of Set 19 | iberia
# city name is  iberia
# Processing Record 23 of Set 19 | gobabis
# city name is  gobabis
# Processing Record 24 of Set 19 | norman wells
# city name is  norman wells
# Processing Record 25 of Set 19 | saurimo
# city name is  saurimo
# Processing Record 26 of Set 19 | koslan
# city name is  koslan
# Processing Record 27 of Set 19 | san patricio
# city name is  san patricio
# Processing Record 28 of Set 19 | hambantota
# city name is  hambantota
# Processing Record 29 of Set 19 | paamiut
# city name is  paamiut
# Processing Record 30 of Set 19 | lavrentiya
# city name is  lavrentiya
# Processing Record 31 of Set 19 | hilo
# city name is  hilo
# Processing Record 32 of Set 19 | maningrida
# city name is  maningrida
# Processing Record 33 of Set 19 | attawapiskat
# city name is  attawapiskat
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 34 of Set 19 | comodoro rivadavia
# city name is  comodoro rivadavia
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 35 of Set 19 | tezu
# city name is  tezu
# Processing Record 36 of Set 19 | dingle
# city name is  dingle
# Processing Record 37 of Set 19 | dargaville
# city name is  dargaville
# Processing Record 38 of Set 19 | oistins
# city name is  oistins
# Processing Record 39 of Set 19 | revelstoke
# city name is  revelstoke
# Processing Record 40 of Set 19 | puerto leguizamo
# city name is  puerto leguizamo
# Processing Record 41 of Set 19 | sindor
# city name is  sindor
# Processing Record 42 of Set 19 | soe
# city name is  soe
# Processing Record 43 of Set 19 | alice springs
# city name is  alice springs
# Processing Record 44 of Set 19 | weiser
# city name is  weiser
# Processing Record 45 of Set 19 | nizhneyansk
# city name is  nizhneyansk
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 46 of Set 19 | sola
# city name is  sola
# Processing Record 47 of Set 19 | mount isa
# city name is  mount isa
# Processing Record 48 of Set 19 | merke
# city name is  merke
# Processing Record 49 of Set 19 | ola
# city name is  ola
# Processing Record 50 of Set 19 | kaitangata
# city name is  kaitangata
# Processing Record 1 of Set 20 | bolshaya dzhalga
# city name is  bolshaya dzhalga
# Processing Record 2 of Set 20 | novovasylivka
# city name is  novovasylivka
# Processing Record 3 of Set 20 | cam pha
# city name is  cam pha
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 4 of Set 20 | celestun
# city name is  celestun
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 5 of Set 20 | kaeo
# city name is  kaeo
# Processing Record 6 of Set 20 | ust-kuyga
# city name is  ust-kuyga
# Processing Record 7 of Set 20 | panama city
# city name is  panama city
# Processing Record 8 of Set 20 | kaputa
# city name is  kaputa
# Processing Record 9 of Set 20 | faanui
# city name is  faanui
# Processing Record 10 of Set 20 | waipawa
# city name is  waipawa
# Processing Record 11 of Set 20 | kandrian
# city name is  kandrian
# Processing Record 12 of Set 20 | nueva gorgona
# city name is  nueva gorgona
# Processing Record 13 of Set 20 | saint anthony
# city name is  saint anthony
# Processing Record 14 of Set 20 | trairi
# city name is  trairi
# Processing Record 15 of Set 20 | vaitupu
# city name is  vaitupu
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 16 of Set 20 | salinas
# city name is  salinas
# Processing Record 17 of Set 20 | satipo
# city name is  satipo
# Processing Record 18 of Set 20 | ostrovnoy
# city name is  ostrovnoy
# Processing Record 19 of Set 20 | ouesso
# city name is  ouesso
# Processing Record 20 of Set 20 | kuche
# city name is  kuche
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 21 of Set 20 | medicine hat
# city name is  medicine hat
# Processing Record 22 of Set 20 | jibuti
# city name is  jibuti
# Processing Record 23 of Set 20 | sao joao da barra
# city name is  sao joao da barra
# Processing Record 24 of Set 20 | mecca
# city name is  mecca
# Processing Record 25 of Set 20 | biltine
# city name is  biltine
# Processing Record 26 of Set 20 | saint-pierre
# city name is  saint-pierre
# Processing Record 27 of Set 20 | cangzhou
# city name is  cangzhou
# Processing Record 28 of Set 20 | aykhal
# city name is  aykhal
# Processing Record 29 of Set 20 | sapozhok
# city name is  sapozhok
# Processing Record 30 of Set 20 | berlevag
# city name is  berlevag
# Processing Record 31 of Set 20 | amderma
# city name is  amderma
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 32 of Set 20 | middle island
# city name is  middle island
# Processing Record 33 of Set 20 | yamada
# city name is  yamada
# Processing Record 34 of Set 20 | hami
# city name is  hami
# Processing Record 35 of Set 20 | gawler
# city name is  gawler
# Processing Record 36 of Set 20 | longyan
# city name is  longyan
# Processing Record 37 of Set 20 | chokurdakh
# city name is  chokurdakh
# Processing Record 38 of Set 20 | port alfred
# city name is  port alfred
# Processing Record 39 of Set 20 | saskatoon
# city name is  saskatoon
# Processing Record 40 of Set 20 | east london
# city name is  east london
# Processing Record 41 of Set 20 | bondo
# city name is  bondo
# Processing Record 42 of Set 20 | marcona
# city name is  marcona
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 43 of Set 20 | haines junction
# city name is  haines junction
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 44 of Set 20 | emmaus
# city name is  emmaus
# Processing Record 45 of Set 20 | esperance
# city name is  esperance
# Processing Record 46 of Set 20 | poya
# city name is  poya
# Processing Record 47 of Set 20 | kouqian
# city name is  kouqian
# Processing Record 48 of Set 20 | ambon
# city name is  ambon
# Processing Record 49 of Set 20 | leningradskiy
# city name is  leningradskiy
# Processing Record 50 of Set 20 | winneba
# city name is  winneba
# Processing Record 1 of Set 21 | kenai
# city name is  kenai
# Processing Record 2 of Set 21 | kodiak
# city name is  kodiak
# Processing Record 3 of Set 21 | ternate
# city name is  ternate
# Processing Record 4 of Set 21 | seguin
# city name is  seguin
# Processing Record 5 of Set 21 | bac lieu
# city name is  bac lieu
# Processing Record 6 of Set 21 | sadovoye
# city name is  sadovoye
# Processing Record 7 of Set 21 | stettler
# city name is  stettler
# Processing Record 8 of Set 21 | ulkan
# city name is  ulkan
# Processing Record 9 of Set 21 | najran
# city name is  najran
# Processing Record 10 of Set 21 | nassogne
# city name is  nassogne
# Processing Record 11 of Set 21 | gat
# city name is  gat
# Processing Record 12 of Set 21 | anacortes
# city name is  anacortes
# Processing Record 13 of Set 21 | buqayq
# city name is  buqayq
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 14 of Set 21 | bambous virieux
# city name is  bambous virieux
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 15 of Set 21 | te anau
# city name is  te anau
# Processing Record 16 of Set 21 | aksarka
# city name is  aksarka
# Processing Record 17 of Set 21 | severo-kurilsk
# city name is  severo-kurilsk
# Processing Record 18 of Set 21 | bonthe
# city name is  bonthe
# Processing Record 19 of Set 21 | steinbach
# city name is  steinbach
# Processing Record 20 of Set 21 | pitimbu
# city name is  pitimbu
# Processing Record 21 of Set 21 | talnakh
# city name is  talnakh
# Processing Record 22 of Set 21 | katsuura
# city name is  katsuura
# Processing Record 23 of Set 21 | buchanan
# city name is  buchanan
# Processing Record 24 of Set 21 | yumen
# city name is  yumen
# Processing Record 25 of Set 21 | lahan
# city name is  lahan
# Processing Record 26 of Set 21 | abu jubayhah
# city name is  abu jubayhah
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 27 of Set 21 | segezha
# city name is  segezha
# Processing Record 28 of Set 21 | roma
# city name is  roma
# Processing Record 29 of Set 21 | beisfjord
# city name is  beisfjord
# Processing Record 30 of Set 21 | santa barbara
# city name is  santa barbara
# Processing Record 31 of Set 21 | katherine
# city name is  katherine
# Processing Record 32 of Set 21 | lawrenceburg
# city name is  lawrenceburg
# Processing Record 33 of Set 21 | namatanai
# city name is  namatanai
# Processing Record 34 of Set 21 | burica
# city name is  burica
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 35 of Set 21 | hamilton
# city name is  hamilton
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 36 of Set 21 | hervey bay
# city name is  hervey bay
# Processing Record 37 of Set 21 | manitouwadge
# city name is  manitouwadge
# Processing Record 38 of Set 21 | murindo
# city name is  murindo
# Processing Record 39 of Set 21 | waingapu
# city name is  waingapu
# Processing Record 40 of Set 21 | geraldton
# city name is  geraldton
# Processing Record 41 of Set 21 | howard springs
# city name is  howard springs
# Processing Record 42 of Set 21 | vangaindrano
# city name is  vangaindrano
# Processing Record 43 of Set 21 | pisco
# city name is  pisco
# Processing Record 44 of Set 21 | bjornevatn
# city name is  bjornevatn
# Processing Record 45 of Set 21 | andapa
# city name is  andapa
# Processing Record 46 of Set 21 | narsaq
# city name is  narsaq
# Processing Record 47 of Set 21 | necochea
# city name is  necochea
# Processing Record 48 of Set 21 | natchez
# city name is  natchez
# Processing Record 49 of Set 21 | nalut
# city name is  nalut
# Processing Record 50 of Set 21 | constitucion
# city name is  constitucion
# Processing Record 1 of Set 22 | fort thomas
# city name is  fort thomas
# Processing Record 2 of Set 22 | ossora
# city name is  ossora
# Processing Record 3 of Set 22 | teya
# city name is  teya
# Processing Record 4 of Set 22 | padang
# city name is  padang
# Processing Record 5 of Set 22 | yeppoon
# city name is  yeppoon
# Processing Record 6 of Set 22 | sitka
# city name is  sitka
# Processing Record 7 of Set 22 | kruisfontein
# city name is  kruisfontein
# Processing Record 8 of Set 22 | palmer
# city name is  palmer
# Processing Record 9 of Set 22 | wucheng
# city name is  wucheng
# Processing Record 10 of Set 22 | ler
# city name is  ler
# Processing Record 11 of Set 22 | haibowan
# city name is  haibowan
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 12 of Set 22 | todos santos
# city name is  todos santos
# Processing Record 13 of Set 22 | shelburne
# city name is  shelburne
# Processing Record 14 of Set 22 | san-pedro
# city name is  san-pedro
# Processing Record 15 of Set 22 | riyadh
# city name is  riyadh
# Processing Record 16 of Set 22 | cantavir
# city name is  cantavir
# Processing Record 17 of Set 22 | torbay
# city name is  torbay
# Processing Record 18 of Set 22 | altay
# city name is  altay
# Processing Record 19 of Set 22 | ormara
# city name is  ormara
# Processing Record 20 of Set 22 | aflu
# city name is  aflu
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 21 of Set 22 | san cristobal
# city name is  san cristobal
# Processing Record 22 of Set 22 | hanna
# city name is  hanna
# Processing Record 23 of Set 22 | praya
# city name is  praya
# Processing Record 24 of Set 22 | kamenskoye
# city name is  kamenskoye
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 25 of Set 22 | rio cuarto
# city name is  rio cuarto
# Processing Record 26 of Set 22 | roebourne
# city name is  roebourne
# Processing Record 27 of Set 22 | tres lagoas
# city name is  tres lagoas
# Processing Record 28 of Set 22 | provideniya
# city name is  provideniya
# Processing Record 29 of Set 22 | takoradi
# city name is  takoradi
# Processing Record 30 of Set 22 | nioki
# city name is  nioki
# Processing Record 31 of Set 22 | cognac
# city name is  cognac
# Processing Record 32 of Set 22 | kiruna
# city name is  kiruna
# Processing Record 33 of Set 22 | isangel
# city name is  isangel
# Processing Record 34 of Set 22 | cockburn town
# city name is  cockburn town
# Processing Record 35 of Set 22 | cortes
# city name is  cortes
# Processing Record 36 of Set 22 | kracheh
# city name is  kracheh
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 37 of Set 22 | bat khela
# city name is  bat khela
# Processing Record 38 of Set 22 | port blair
# city name is  port blair
# Processing Record 39 of Set 22 | belmonte
# city name is  belmonte
# Processing Record 40 of Set 22 | ipanema
# city name is  ipanema
# Processing Record 41 of Set 22 | bako
# city name is  bako
# Processing Record 42 of Set 22 | luderitz
# city name is  luderitz
# Processing Record 43 of Set 22 | victoria
# city name is  victoria
# Processing Record 44 of Set 22 | rawson
# city name is  rawson
# Processing Record 45 of Set 22 | wuda
# city name is  wuda
# Processing Record 46 of Set 22 | itamarandiba
# city name is  itamarandiba
# Processing Record 47 of Set 22 | marsh harbour
# city name is  marsh harbour
# Processing Record 48 of Set 22 | la union
# city name is  la union
# Processing Record 49 of Set 22 | kahului
# city name is  kahului
# Processing Record 50 of Set 22 | baruun-urt
# city name is  baruun-urt
# Processing Record 1 of Set 23 | konstantinovka
# city name is  konstantinovka
# Processing Record 2 of Set 23 | tumannyy
# city name is  tumannyy
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 3 of Set 23 | mbanza-ngungu
# city name is  mbanza-ngungu
# Processing Record 4 of Set 23 | labuhan
# city name is  labuhan
# Processing Record 5 of Set 23 | homer
# city name is  homer
# Processing Record 6 of Set 23 | tiruchchirappalli
# city name is  tiruchchirappalli
# Processing Record 7 of Set 23 | grand centre
# city name is  grand centre
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 8 of Set 23 | pirovskoye
# city name is  pirovskoye
# Processing Record 9 of Set 23 | winfield
# city name is  winfield
# Processing Record 10 of Set 23 | bonito
# city name is  bonito
# Processing Record 11 of Set 23 | port lincoln
# city name is  port lincoln
# Processing Record 12 of Set 23 | shimoda
# city name is  shimoda
# Processing Record 13 of Set 23 | pauini
# city name is  pauini
# Processing Record 14 of Set 23 | salalah
# city name is  salalah
# Processing Record 15 of Set 23 | olinda
# city name is  olinda
# Processing Record 16 of Set 23 | paso de los toros
# city name is  paso de los toros
# Processing Record 17 of Set 23 | cabo san lucas
# city name is  cabo san lucas
# Processing Record 18 of Set 23 | la orilla
# city name is  la orilla
# Processing Record 19 of Set 23 | palana
# city name is  palana
# Processing Record 20 of Set 23 | college
# city name is  college
# Processing Record 21 of Set 23 | pevek
# city name is  pevek
# Processing Record 22 of Set 23 | nokaneng
# city name is  nokaneng
# Processing Record 23 of Set 23 | arlit
# city name is  arlit
# Processing Record 24 of Set 23 | beringovskiy
# city name is  beringovskiy
# Processing Record 25 of Set 23 | davila
# city name is  davila
# Processing Record 26 of Set 23 | bodden town
# city name is  bodden town
# Processing Record 27 of Set 23 | bandarbeyla
# city name is  bandarbeyla
# Processing Record 28 of Set 23 | pacifica
# city name is  pacifica
# Processing Record 29 of Set 23 | north platte
# city name is  north platte
# Processing Record 30 of Set 23 | romny
# city name is  romny
# Processing Record 31 of Set 23 | saleaula
# city name is  saleaula
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 32 of Set 23 | vilyuysk
# city name is  vilyuysk
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 33 of Set 23 | sivas
# city name is  sivas
# Processing Record 34 of Set 23 | havelock
# city name is  havelock
# Processing Record 35 of Set 23 | sao sebastiao
# city name is  sao sebastiao
# Processing Record 36 of Set 23 | vestmanna
# city name is  vestmanna
# Processing Record 37 of Set 23 | port elizabeth
# city name is  port elizabeth
# Processing Record 38 of Set 23 | martapura
# city name is  martapura
# Processing Record 39 of Set 23 | sakakah
# city name is  sakakah
# Processing Record 40 of Set 23 | acajutla
# city name is  acajutla
# Processing Record 41 of Set 23 | lengshuitan
# city name is  lengshuitan
# Processing Record 42 of Set 23 | toumodi
# city name is  toumodi
# Processing Record 43 of Set 23 | gizo
# city name is  gizo
# Processing Record 44 of Set 23 | peniche
# city name is  peniche
# Processing Record 45 of Set 23 | san quintin
# city name is  san quintin
# Processing Record 46 of Set 23 | trinidad
# city name is  trinidad
# Processing Record 47 of Set 23 | natal
# city name is  natal
# Processing Record 48 of Set 23 | port-cartier
# city name is  port-cartier
# Processing Record 49 of Set 23 | sarankhola
# city name is  sarankhola
# Processing Record 50 of Set 23 | bolonchen
# city name is  bolonchen
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 1 of Set 24 | bollnas
# city name is  bollnas
# Processing Record 2 of Set 24 | severnyy
# city name is  severnyy
# Processing Record 3 of Set 24 | dikson
# city name is  dikson
# Processing Record 4 of Set 24 | vanimo
# city name is  vanimo
# Processing Record 5 of Set 24 | laguna
# city name is  laguna
# Processing Record 6 of Set 24 | tevaitoa
# city name is  tevaitoa
# Processing Record 7 of Set 24 | arcachon
# city name is  arcachon
# Processing Record 8 of Set 24 | prince rupert
# city name is  prince rupert
# Processing Record 9 of Set 24 | pangoa
# city name is  pangoa
# Processing Record 10 of Set 24 | myaundzha
# city name is  myaundzha
# Processing Record 11 of Set 24 | kropotkin
# city name is  kropotkin
# Processing Record 12 of Set 24 | hirara
# city name is  hirara
# Processing Record 13 of Set 24 | sal rei
# city name is  sal rei
# Processing Record 14 of Set 24 | port hedland
# city name is  port hedland
# Processing Record 15 of Set 24 | avera
# city name is  avera
# Processing Record 16 of Set 24 | faya
# city name is  faya
# Processing Record 17 of Set 24 | batemans bay
# city name is  batemans bay
# Processing Record 18 of Set 24 | basco
# city name is  basco
# Processing Record 19 of Set 24 | yar-sale
# city name is  yar-sale
# Processing Record 20 of Set 24 | khed brahma
# city name is  khed brahma
# Processing Record 21 of Set 24 | furano
# city name is  furano
# Processing Record 22 of Set 24 | aleksin
# city name is  aleksin
# Processing Record 23 of Set 24 | saint-augustin
# city name is  saint-augustin
# Processing Record 24 of Set 24 | astana
# city name is  astana
# Processing Record 25 of Set 24 | sangar
# city name is  sangar
# Processing Record 26 of Set 24 | karaul
# city name is  karaul
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 27 of Set 24 | praia
# city name is  praia
# Processing Record 28 of Set 24 | axim
# city name is  axim
# Processing Record 29 of Set 24 | tibati
# city name is  tibati
# Processing Record 30 of Set 24 | chateaubelair
# city name is  chateaubelair
# Processing Record 31 of Set 24 | tura
# city name is  tura
# Processing Record 32 of Set 24 | naron
# city name is  naron
# Processing Record 33 of Set 24 | lolua
# city name is  lolua
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 34 of Set 24 | west plains
# city name is  west plains
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 35 of Set 24 | huarmey
# city name is  huarmey
# Processing Record 36 of Set 24 | deputatskiy
# city name is  deputatskiy
# Processing Record 37 of Set 24 | roxana
# city name is  roxana
# Processing Record 38 of Set 24 | ca mau
# city name is  ca mau
# Processing Record 39 of Set 24 | rio verde de mato grosso
# city name is  rio verde de mato grosso
# Processing Record 40 of Set 24 | bay city
# city name is  bay city
# Processing Record 41 of Set 24 | awjilah
# city name is  awjilah
# Processing Record 42 of Set 24 | havre
# city name is  havre
# Processing Record 43 of Set 24 | itupeva
# city name is  itupeva
# Processing Record 44 of Set 24 | auxerre
# city name is  auxerre
# Processing Record 45 of Set 24 | tabuk
# city name is  tabuk
# Processing Record 46 of Set 24 | nong kung si
# city name is  nong kung si
# Processing Record 47 of Set 24 | tazovskiy
# city name is  tazovskiy
# Processing Record 48 of Set 24 | edd
# city name is  edd
# Processing Record 49 of Set 24 | georgiyevskoye
# city name is  georgiyevskoye
# Processing Record 50 of Set 24 | north bend
# city name is  north bend
# Processing Record 1 of Set 25 | zavyalovo
# city name is  zavyalovo
# Processing Record 2 of Set 25 | northam
# city name is  northam
# Processing Record 3 of Set 25 | alice town
# city name is  alice town
# Processing Record 4 of Set 25 | yaan
# city name is  yaan
# Processing Record 5 of Set 25 | boyolangu
# city name is  boyolangu
# Processing Record 6 of Set 25 | broome
# city name is  broome
# Processing Record 7 of Set 25 | mayumba
# city name is  mayumba
# Processing Record 8 of Set 25 | taree
# city name is  taree
# Processing Record 9 of Set 25 | guisijan
# city name is  guisijan
# Processing Record 10 of Set 25 | richards bay
# city name is  richards bay
# Processing Record 11 of Set 25 | johi
# city name is  johi
# Processing Record 12 of Set 25 | iqaluit
# city name is  iqaluit
# Processing Record 13 of Set 25 | praia da vitoria
# city name is  praia da vitoria
# Processing Record 14 of Set 25 | byron bay
# city name is  byron bay
# Processing Record 15 of Set 25 | hamina
# city name is  hamina
# Processing Record 16 of Set 25 | grand gaube
# city name is  grand gaube
# Processing Record 17 of Set 25 | aklavik
# city name is  aklavik
# Processing Record 18 of Set 25 | zonguldak
# city name is  zonguldak
# Processing Record 19 of Set 25 | yushan
# city name is  yushan
# Processing Record 20 of Set 25 | margate
# city name is  margate
# Processing Record 21 of Set 25 | fabianhaza
# city name is  fabianhaza
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 22 of Set 25 | hyeres
# city name is  hyeres
# Processing Record 23 of Set 25 | uzunovo
# city name is  uzunovo
# Processing Record 24 of Set 25 | wewak
# city name is  wewak
# Processing Record 25 of Set 25 | chapais
# city name is  chapais
# Processing Record 26 of Set 25 | atamanovka
# city name is  atamanovka
# Processing Record 27 of Set 25 | tinyahuarco
# city name is  tinyahuarco
# Processing Record 28 of Set 25 | rafaela
# city name is  rafaela
# Processing Record 29 of Set 25 | pekin
# city name is  pekin
# Processing Record 30 of Set 25 | varska
# city name is  varska
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 31 of Set 25 | jilib
# city name is  jilib
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 32 of Set 25 | antofagasta
# city name is  antofagasta
# Processing Record 33 of Set 25 | karkaralinsk
# city name is  karkaralinsk
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 34 of Set 25 | haapu
# city name is  haapu
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 35 of Set 25 | aguimes
# city name is  aguimes
# Processing Record 36 of Set 25 | frederick
# city name is  frederick
# Processing Record 37 of Set 25 | yulara
# city name is  yulara
# Processing Record 38 of Set 25 | vila franca do campo
# city name is  vila franca do campo
# Processing Record 39 of Set 25 | ahipara
# city name is  ahipara
# Processing Record 40 of Set 25 | bargal
# city name is  bargal
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 41 of Set 25 | takaka
# city name is  takaka
# Processing Record 42 of Set 25 | guerrero negro
# city name is  guerrero negro
# Processing Record 43 of Set 25 | vaxjo
# city name is  vaxjo
# Processing Record 44 of Set 25 | kirillov
# city name is  kirillov
# Processing Record 45 of Set 25 | bulawayo
# city name is  bulawayo
# Processing Record 46 of Set 25 | ouro preto do oeste
# city name is  ouro preto do oeste
# Processing Record 47 of Set 25 | coxim
# city name is  coxim
# Processing Record 48 of Set 25 | zhigansk
# city name is  zhigansk
# Processing Record 49 of Set 25 | mnogovershinnyy
# city name is  mnogovershinnyy
# Processing Record 50 of Set 25 | nara
# city name is  nara
# Processing Record 1 of Set 26 | baripada
# city name is  baripada
# Processing Record 2 of Set 26 | caravelas
# city name is  caravelas
# Processing Record 3 of Set 26 | senmonorom
# city name is  senmonorom
# error in the code is
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# 'sys'
# City not found. Skipping...
# Processing Record 4 of Set 26 | carutapera
# city name is  carutapera
# Processing Record 5 of Set 26 | tierra blanca
# city name is  tierra blanca
# Processing Record 6 of Set 26 | joensuu
# city name is  joensuu
# Processing Record 7 of Set 26 | adrar
# city name is  adrar
# Processing Record 8 of Set 26 | aljezur
# city name is  aljezur
# Processing Record 9 of Set 26 | guymon
# city name is  guymon
# Processing Record 10 of Set 26 | saint-joseph
# city name is  saint-joseph
# Processing Record 11 of Set 26 | volksrust
# city name is  volksrust
# Processing Record 12 of Set 26 | cabedelo
# city name is  cabedelo
# Processing Record 13 of Set 26 | rajpipla
# city name is  rajpipla
# Processing Record 14 of Set 26 | bahia blanca
# city name is  bahia blanca
# Processing Record 15 of Set 26 | ketchikan
# city name is  ketchikan
# Processing Record 16 of Set 26 | lazaro cardenas
# city name is  lazaro cardenas
# Processing Record 17 of Set 26 | panacan
# city name is  panacan
# Processing Record 18 of Set 26 | syava
# city name is  syava
# Processing Record 19 of Set 26 | penzance
# city name is  penzance
# Processing Record 20 of Set 26 | portland
# city name is  portland
# Processing Record 21 of Set 26 | kinsale
# city name is  kinsale
# Processing Record 22 of Set 26 | arrifes
# city name is  arrifes
# Processing Record 23 of Set 26 | slobidka
# city name is  slobidka
# Processing Record 24 of Set 26 | batticaloa
# city name is  batticaloa
# Processing Record 25 of Set 26 | bojonegoro
# city name is  bojonegoro
# Processing Record 26 of Set 26 | menongue
# city name is  menongue
# Processing Record 27 of Set 26 | moranbah
# city name is  moranbah
# Processing Record 28 of Set 26 | maragogi
# city name is  maragogi
# Processing Record 29 of Set 26 | hofn
# city name is  hofn
# Processing Record 30 of Set 26 | bayji
# city name is  bayji
# Processing Record 31 of Set 26 | saint george
# city name is  saint george
# Processing Record 32 of Set 26 | aripuana
# city name is  aripuana
# Processing Record 33 of Set 26 | beni mazar
# city name is  beni mazar
# Processing Record 34 of Set 26 | liwale
# city name is  liwale
# Processing Record 35 of Set 26 | abramovka
# city name is  abramovka
# Processing Record 36 of Set 26 | flin flon
# city name is  flin flon
# Processing Record 37 of Set 26 | along
# city name is  along
# Processing Record 38 of Set 26 | shenavan
# city name is  shenavan
# Processing Record 39 of Set 26 | pozo colorado
# city name is  pozo colorado
# Processing Record 40 of Set 26 | lompoc
# city name is  lompoc
# Processing Record 41 of Set 26 | sioux falls
# city name is  sioux falls
# Processing Record 42 of Set 26 | araouane
# city name is  araouane
# Processing Record 43 of Set 26 | xining
# city name is  xining
# Processing Record 44 of Set 26 | jaffna
# city name is  jaffna
# Processing Record 45 of Set 26 | lukow
# city name is  lukow
# Processing Record 46 of Set 26 | almeirim
# city name is  almeirim
# Processing Record 47 of Set 26 | balabac
# city name is  balabac
# Processing Record 48 of Set 26 | khovu-aksy
# city name is  khovu-aksy
# Processing Record 49 of Set 26 | riverbank
# city name is  riverbank
# Processing Record 50 of Set 26 | orange walk
# city name is  orange walk
# Processing Record 1 of Set 27 | cravo norte
# city name is  cravo norte
# Processing Record 2 of Set 27 | ugoofaaru
# city name is  ugoofaaru
# Processing Record 3 of Set 27 | isla mujeres
# city name is  isla mujeres
# Processing Record 4 of Set 27 | samarai
# city name is  samarai
# Processing Record 5 of Set 27 | taketa
# city name is  taketa
# Processing Record 6 of Set 27 | kodinsk
# city name is  kodinsk
# Processing Record 7 of Set 27 | agirish
# city name is  agirish
# Processing Record 8 of Set 27 | kuybysheve
# city name is  kuybysheve
# Processing Record 9 of Set 27 | bubaque
# city name is  bubaque
# Processing Record 10 of Set 27 | aldan
# city name is  aldan
# Processing Record 11 of Set 27 | la rioja
# city name is  la rioja
# Processing Record 12 of Set 27 | utiroa
# city name is  utiroa
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 13 of Set 27 | alihe
# city name is  alihe
# Processing Record 14 of Set 27 | coihaique
# city name is  coihaique
# Processing Record 15 of Set 27 | soyo
# city name is  soyo
# Processing Record 16 of Set 27 | kazerun
# city name is  kazerun
# Processing Record 17 of Set 27 | saryshagan
# city name is  saryshagan
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 18 of Set 27 | qui nhon
# city name is  qui nhon
# Processing Record 19 of Set 27 | lerwick
# city name is  lerwick
# Processing Record 20 of Set 27 | komsomolskiy
# city name is  komsomolskiy
# Processing Record 21 of Set 27 | zhanaozen
# city name is  zhanaozen
# Processing Record 22 of Set 27 | laguna de perlas
# city name is  laguna de perlas
# Processing Record 23 of Set 27 | ha tinh
# city name is  ha tinh
# Processing Record 24 of Set 27 | seoul
# city name is  seoul
# ...
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 45 of Set 27 | qiongshan
# city name is  qiongshan
# Processing Record 46 of Set 27 | kamen-rybolov
# city name is  kamen-rybolov
# Processing Record 47 of Set 27 | puerto carreno
# city name is  puerto carreno
# Processing Record 48 of Set 27 | puerto del rosario
# city name is  puerto del rosario
# Processing Record 49 of Set 27 | firozpur jhirka
# city name is  firozpur jhirka
# Processing Record 50 of Set 27 | nouakchott
# city name is  nouakchott
# Processing Record 1 of Set 28 | fairbanks
# city name is  fairbanks
# Processing Record 2 of Set 28 | dalinghe
# city name is  dalinghe
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 3 of Set 28 | itaguai
# city name is  itaguai
# Processing Record 4 of Set 28 | bengkulu
# city name is  bengkulu
# Processing Record 5 of Set 28 | palabuhanratu
# city name is  palabuhanratu
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 6 of Set 28 | doctor arroyo
# city name is  doctor arroyo
# Processing Record 7 of Set 28 | letterkenny
# city name is  letterkenny
# Processing Record 8 of Set 28 | jinchang
# city name is  jinchang
# Processing Record 9 of Set 28 | louisbourg
# city name is  louisbourg
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 10 of Set 28 | mazamari
# city name is  mazamari
# Processing Record 11 of Set 28 | panaba
# city name is  panaba
# Processing Record 12 of Set 28 | zaliztsi
# city name is  zaliztsi
# Processing Record 13 of Set 28 | svetlyy
# city name is  svetlyy
# Processing Record 14 of Set 28 | maarianhamina
# city name is  maarianhamina
# Processing Record 15 of Set 28 | hualmay
# city name is  hualmay
# Processing Record 16 of Set 28 | samusu
# city name is  samusu
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 17 of Set 28 | cayenne
# city name is  cayenne
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 18 of Set 28 | kirensk
# city name is  kirensk
# Processing Record 19 of Set 28 | meadow lake
# city name is  meadow lake
# Processing Record 20 of Set 28 | beira
# city name is  beira
# Processing Record 21 of Set 28 | raudeberg
# city name is  raudeberg
# Processing Record 22 of Set 28 | changtu
# city name is  changtu
# Processing Record 23 of Set 28 | lana
# city name is  lana
# Processing Record 24 of Set 28 | galgani
# city name is  galgani
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 25 of Set 28 | cockburn harbour
# city name is  cockburn harbour
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 26 of Set 28 | taburi
# city name is  taburi
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 27 of Set 28 | pangkalanbuun
# city name is  pangkalanbuun
# Processing Record 28 of Set 28 | pangody
# city name is  pangody
# Processing Record 29 of Set 28 | ixtapa
# city name is  ixtapa
# Processing Record 30 of Set 28 | muika
# city name is  muika
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 31 of Set 28 | puerto penasco
# city name is  puerto penasco
# Processing Record 32 of Set 28 | walvis bay
# city name is  walvis bay
# Processing Record 33 of Set 28 | sisimiut
# city name is  sisimiut
# Processing Record 34 of Set 28 | verkhovazhye
# city name is  verkhovazhye
# Processing Record 35 of Set 28 | hasaki
# city name is  hasaki
# Processing Record 36 of Set 28 | benghazi
# city name is  benghazi
# Processing Record 37 of Set 28 | felidhoo
# city name is  felidhoo
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 38 of Set 28 | general pico
# city name is  general pico
# Processing Record 39 of Set 28 | barbar
# city name is  barbar
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 40 of Set 28 | vilkija
# city name is  vilkija
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 41 of Set 28 | bagotville
# city name is  bagotville
# Processing Record 42 of Set 28 | marsaxlokk
# city name is  marsaxlokk
# Processing Record 43 of Set 28 | rassvet
# city name is  rassvet
# Processing Record 44 of Set 28 | nador
# city name is  nador
# Processing Record 45 of Set 28 | nova granada
# city name is  nova granada
# Processing Record 46 of Set 28 | puerto narino
# city name is  puerto narino
# Processing Record 47 of Set 28 | himora
# city name is  himora
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 48 of Set 28 | san lorenzo
# city name is  san lorenzo
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 49 of Set 28 | omsukchan
# city name is  omsukchan
# Processing Record 50 of Set 28 | hobyo
# city name is  hobyo
# Processing Record 1 of Set 29 | madera
# city name is  madera
# Processing Record 2 of Set 29 | darhan
# city name is  darhan
# Processing Record 3 of Set 29 | jiuquan
# city name is  jiuquan
# Processing Record 4 of Set 29 | ituni
# city name is  ituni
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 5 of Set 29 | shieli
# city name is  shieli
# Processing Record 6 of Set 29 | nhulunbuy
# city name is  nhulunbuy
# Processing Record 7 of Set 29 | olafsvik
# city name is  olafsvik
# Processing Record 8 of Set 29 | nguiu
# city name is  nguiu
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 9 of Set 29 | muros
# city name is  muros
# Processing Record 10 of Set 29 | xiuyan
# city name is  xiuyan
# Processing Record 11 of Set 29 | lincoln
# city name is  lincoln
# Processing Record 12 of Set 29 | palghar
# city name is  palghar
# Processing Record 13 of Set 29 | santa cruz
# city name is  santa cruz
# Processing Record 14 of Set 29 | portsoy
# city name is  portsoy
# Processing Record 15 of Set 29 | puerto madryn
# city name is  puerto madryn
# Processing Record 16 of Set 29 | whitehorse
# city name is  whitehorse
# Processing Record 17 of Set 29 | fort saint james
# city name is  fort saint james
# Processing Record 18 of Set 29 | khorramabad
# city name is  khorramabad
# Processing Record 19 of Set 29 | ouallam
# city name is  ouallam
# Processing Record 20 of Set 29 | ekibastuz
# city name is  ekibastuz
# Processing Record 21 of Set 29 | kayerkan
# city name is  kayerkan
# Processing Record 22 of Set 29 | rungata
# city name is  rungata
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 23 of Set 29 | tiznit
# city name is  tiznit
# Processing Record 24 of Set 29 | perigueux
# city name is  perigueux
# Processing Record 25 of Set 29 | matara
# city name is  matara
# Processing Record 26 of Set 29 | talavera de la reina
# city name is  talavera de la reina
# Processing Record 27 of Set 29 | cochrane
# city name is  cochrane
# Processing Record 28 of Set 29 | fukue
# city name is  fukue
# Processing Record 29 of Set 29 | mombetsu
# city name is  mombetsu
# Processing Record 30 of Set 29 | sault sainte marie
# city name is  sault sainte marie
# Processing Record 31 of Set 29 | graham
# city name is  graham
# Processing Record 32 of Set 29 | solsvik
# city name is  solsvik
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 33 of Set 29 | charters towers
# city name is  charters towers
# Processing Record 34 of Set 29 | lahij
# city name is  lahij
# Processing Record 35 of Set 29 | naze
# city name is  naze
# Processing Record 36 of Set 29 | mitu
# city name is  mitu
# Processing Record 37 of Set 29 | oxford
# city name is  oxford
# Processing Record 38 of Set 29 | douglas
# city name is  douglas
# Processing Record 39 of Set 29 | fredericton
# city name is  fredericton
# Processing Record 40 of Set 29 | kalabo
# city name is  kalabo
# Processing Record 41 of Set 29 | joinville
# city name is  joinville
# Processing Record 42 of Set 29 | coquimbo
# city name is  coquimbo
# Processing Record 43 of Set 29 | grand island
# city name is  grand island
# Processing Record 44 of Set 29 | vestmannaeyjar
# city name is  vestmannaeyjar
# Processing Record 45 of Set 29 | banda aceh
# city name is  banda aceh
# Processing Record 46 of Set 29 | cerrito
# city name is  cerrito
# Processing Record 47 of Set 29 | pacific grove
# city name is  pacific grove
# Processing Record 48 of Set 29 | porto novo
# city name is  porto novo
# Processing Record 49 of Set 29 | iquique
# city name is  iquique
# Processing Record 50 of Set 29 | ordu
# city name is  ordu
# Processing Record 1 of Set 30 | ust-kan
# city name is  ust-kan
# Processing Record 2 of Set 30 | lima
# city name is  lima
# Processing Record 3 of Set 30 | amuntai
# city name is  amuntai
# Processing Record 4 of Set 30 | moron
# city name is  moron
# Processing Record 5 of Set 30 | pachino
# city name is  pachino
# Processing Record 6 of Set 30 | gasa
# city name is  gasa
# Processing Record 7 of Set 30 | maceio
# city name is  maceio
# Processing Record 8 of Set 30 | porto santo
# city name is  porto santo
# Processing Record 9 of Set 30 | paraiso
# city name is  paraiso
# Processing Record 10 of Set 30 | marsa matruh
# city name is  marsa matruh
# Processing Record 11 of Set 30 | tucume
# city name is  tucume
# Processing Record 12 of Set 30 | petropavlovsk-kamchatskiy
# city name is  petropavlovsk-kamchatskiy
# Processing Record 13 of Set 30 | marang
# city name is  marang
# Processing Record 14 of Set 30 | sironko
# city name is  sironko
# Processing Record 15 of Set 30 | bowen
# city name is  bowen
# Processing Record 16 of Set 30 | tapa
# city name is  tapa
# Processing Record 17 of Set 30 | verkhoyansk
# city name is  verkhoyansk
# Processing Record 18 of Set 30 | kano
# city name is  kano
# Processing Record 19 of Set 30 | daultala
# city name is  daultala
# Processing Record 20 of Set 30 | genhe
# city name is  genhe
# Processing Record 21 of Set 30 | shakhtinsk
# city name is  shakhtinsk
# Processing Record 22 of Set 30 | chia
# city name is  chia
# Processing Record 23 of Set 30 | yakeshi
# city name is  yakeshi
# Processing Record 24 of Set 30 | opuwo
# city name is  opuwo
# Processing Record 25 of Set 30 | egvekinot
# city name is  egvekinot
# Processing Record 26 of Set 30 | paveh
# city name is  paveh
# Processing Record 27 of Set 30 | korla
# city name is  korla
# Processing Record 28 of Set 30 | mwanza
# city name is  mwanza
# Processing Record 29 of Set 30 | vung tau
# city name is  vung tau
# Processing Record 30 of Set 30 | mweka
# city name is  mweka
# Processing Record 31 of Set 30 | zinder
# city name is  zinder
# Processing Record 32 of Set 30 | alyangula
# city name is  alyangula
# Processing Record 33 of Set 30 | alindao
# city name is  alindao
# Processing Record 34 of Set 30 | jaciara
# city name is  jaciara
# Processing Record 35 of Set 30 | gumdag
# city name is  gumdag
# Processing Record 36 of Set 30 | sarkand
# city name is  sarkand
# Processing Record 37 of Set 30 | shu
# city name is  shu
# Processing Record 38 of Set 30 | tokomaru
# city name is  tokomaru
# Processing Record 39 of Set 30 | orsha
# city name is  orsha
# Processing Record 40 of Set 30 | flinders
# city name is  flinders
# Processing Record 41 of Set 30 | srednyaya akhtuba
# city name is  srednyaya akhtuba
# Processing Record 42 of Set 30 | teterow
# city name is  teterow
# Processing Record 43 of Set 30 | dongkan
# city name is  dongkan
# Processing Record 44 of Set 30 | alma
# city name is  alma
# Processing Record 45 of Set 30 | alofi
# city name is  alofi
# Processing Record 46 of Set 30 | jiwani
# city name is  jiwani
# Processing Record 47 of Set 30 | zhuanghe
# city name is  zhuanghe
# Processing Record 48 of Set 30 | mercedes
# city name is  mercedes
# Processing Record 49 of Set 30 | sorocaba
# city name is  sorocaba
# Processing Record 50 of Set 30 | lakes entrance
# city name is  lakes entrance
# Processing Record 1 of Set 31 | nederland
# city name is  nederland
# Processing Record 2 of Set 31 | barcelos
# city name is  barcelos
# Processing Record 3 of Set 31 | trat
# city name is  trat
# Processing Record 4 of Set 31 | taltal
# city name is  taltal
# Processing Record 5 of Set 31 | wahran
# city name is  wahran
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 6 of Set 31 | marrakesh
# city name is  marrakesh
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# Processing Record 7 of Set 31 | kloulklubed
# city name is  kloulklubed
# Processing Record 8 of Set 31 | falealupo
# city name is  falealupo
# Traceback (most recent call last):
#   File "<ipython-input-129-d898b442582e>", line 22, in <module>
#     city_country = city_weather["sys"]["country"]
# KeyError: 'sys'
# error in the code is 'sys'
# City not found. Skipping...
# Processing Record 9 of Set 31 | loreto
# city name is  loreto
# Processing Record 10 of Set 31 | dubbo
# city name is  dubbo
# Processing Record 11 of Set 31 | aktau
# city name is  aktau
# Processing Record 12 of Set 31 | port augusta
# city name is  port augusta
# Processing Record 13 of Set 31 | monywa
# city name is  monywa
# Processing Record 14 of Set 31 | phangnga
# city name is  phangnga
# Processing Record 15 of Set 31 | asyut
# city name is  asyut
# Processing Record 16 of Set 31 | ghanzi
# city name is  ghanzi
# Processing Record 17 of Set 31 | misratah
# city name is  misratah
# Processing Record 18 of Set 31 | tulangan
# city name is  tulangan
# Processing Record 19 of Set 31 | scarborough
# city name is  scarborough
# Processing Record 20 of Set 31 | tutoia
# city name is  tutoia
# Processing Record 21 of Set 31 | suzaka
# city name is  suzaka
# Processing Record 22 of Set 31 | vostok
# city name is  vostok
# Processing Record 23 of Set 31 | kupiskis
# city name is  kupiskis
# Processing Record 24 of Set 31 | hatillo
# city name is  hatillo
# Processing Record 25 of Set 31 | morant bay
# city name is  morant bay
# Processing Record 26 of Set 31 | aketi
# city name is  aketi
# Processing Record 27 of Set 31 | tucupita
# city name is  tucupita
# Processing Record 28 of Set 31 | vila velha
# city name is  vila velha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Souillac      MU -20.5167   57.5167     71.37        80          19
# 1        Avarua      CK -21.2078 -159.7750     78.85        78          90
# 2       Linares      CL -35.8500  -71.6000     58.86        70          63
# 3      Hermanus      ZA -34.4187   19.2345     60.80        87          24
# 4        Laguna      US  38.4210 -121.4238     98.20        34           1
# ..          ...     ...      ...       ...       ...       ...         ...
# 673       Belen      TR  36.4891   36.2233     65.03        72           0
# 674     Marivan      IR  35.5219   46.1760     56.88        56           0
# 675      Bolobo      CD  -2.1667   16.2333     74.68        73          63
# 676   Qiongshan      CN  20.0058  110.3542     75.18        94           0
# 677  Balkanabat      TM  39.5108   54.3671     72.43        56           0
#
#      Wind Speed Current Description
# 0         17.52          few clouds
# 1         16.11          light rain
# 2          2.44       broken clouds
# 3         11.10          few clouds
# 4          5.01           clear sky
# ..          ...                 ...
# 673        2.30           clear sky
# 674        1.48           clear sky
# 675        2.30       broken clouds
# 676        4.47          light rain
# 677        6.96           clear sky
#
# [678 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
